# %% [markdown]
# # WordCount

# %%
# -*- coding: utf-8 -*-
from hazm import *
import itertools
Text = ":(((()))) متن‌کاوي، سلللاااامممم به داده‌کاوی‌ای که بر روی متن ها انجام شود اشااررررره دارد. همچنین به عنوان آنالیز متن نیز شناخته می‌شود که منظور از آن فرایندها استخراج مکرر اطلاعات با کیفیت از متن است. اطلاعات پر کیفیت، به‌طور معمول از فهم الگوها و گرایش‌ها از طریق معانی و به وسیلهٔ یادگیری الگوهای آماری حاصل می‌شود. متن کاوی معمولاً درگیر در فرایند ساختاردهی به ورودی‌های متنی (معمولاً تجزیه، همراه با افزودن برخی ویژگی‌ها تفاسیر زبانی و حذف موارد اضافی و درج موارد بعدی در پایگاه داده انجام می‌گیرد)، استخراج الگوهای درون داده‌های ساختار یافته، و در نهایت ارزیابی و تفسیر خروجی‌ها است. «پر کیفیت» در متن کاوی معمولاً به ترکیبی از مرتبط بودن، نو ظهور بودن و جالب بودن اشاره دارد. وظایف متن کاوی معمول شامل دسته‌بندی متون، خوشه بندی متون، استخراج معنی و مفهوم، تولید رده‌بندی دانه‌ای، تجزیه و تحلیل احساسات، خلاصه کردن اسناد و مدلسازی ارتباط موجودیت‌ها است. (بطور مثال یادگیری ارتباط بین موجودیتها) آنالیز متن درگیر در بازیابی اطلاعات، آنالیز لغوی برای مطالعه توزیع فرکانس لغات، شناخت الگو، برچسب گذاری/حاشیه نویسی، استخراج اطلاعات، تکنیک‌های داده کاوی شامل آنالیز اتصال و ارتباط، بصری سازی، و آنالیز پیشگویانه است. هدف نهایی، اساساً تبدیل متن به داده برای آنالیز از طریق کاربرد پردازش زبان‌های طبیعی و متدهای تحلیلی است. یک کاربرد معمول، جهت اسکن مجموعه‌ای از اسناد نوشته شده در یک زبان طبیعی و مدل کردن مجموعه اسناد برای اهداف کلاس‌بندی پیشگویانه یا پرکردن یک پایگاه داده یا ایندکس جستجو با اطلاعات استخراج شده‌است"


normalizer = Normalizer()
textnor = normalizer.normalize(Text)

textnor = textnor.replace("\u200c"," ")
textnor = ''.join(ch for ch, _ in itertools.groupby(textnor))
print(textnor)
# Out:
# : () متن کاوی، سلام به داده کاوی ای که بر روی متن ها انجام شود اشاره دارد. همچنین به عنوان آنالیز متن نیز شناخته می شود که منظور از آن فرایندها استخراج مکر اطلاعات با کیفیت از متن است. اطلاعات پر کیفیت، به طور معمول از فهم الگوها و گرایش ها از طریق معانی و به وسیلهٔ یادگیری الگوهای آماری حاصل می شود. متن کاوی معمولاً درگیر در فرایند ساختاردهی به ورودی های متنی (معمولاً تجزیه، همراه با افزودن برخی ویژگی ها تفاسیر زبانی و حذف موارد اضافی و درج موارد بعدی در پایگاه داده انجام می گیرد)، استخراج الگوهای درون داده های ساختار یافته، و در نهایت ارزیابی و تفسیر خروجی ها است. «پر کیفیت» در متن کاوی معمولاً به ترکیبی از مرتبط بودن، نو ظهور بودن و جالب بودن اشاره دارد. وظایف متن کاوی معمول شامل دسته بندی متون، خوشه بندی متون، استخراج معنی و مفهوم، تولید رده بندی دانه ای، تجزیه و تحلیل احساسات، خلاصه کردن اسناد و مدلسازی ارتباط موجودیت ها است. (بطور مثال یادگیری ارتباط بین موجودیتها) آنالیز متن درگیر در بازیابی اطلاعات، آنالیز لغوی برای مطالعه توزیع فرکانس لغات، شناخت الگو، برچسب گذاری/حاشیه نویسی، استخراج اطلاعات، تکنیک های داده کاوی شامل آنالیز اتصال و ارتباط، بصری سازی، و آنالیز پیشگویانه است. هدف نهای، اساساً تبدیل متن به داده برای آنالیز از طریق کاربرد پردازش زبان های طبیعی و متدهای تحلیلی است. یک کاربرد معمول، جهت اسکن مجموعه ای از اسناد نوشته شده در یک زبان طبیعی و مدل کردن مجموعه اسناد برای اهداف کلاس بندی پیشگویانه یا پرکردن یک پایگاه داده یا ایندکس جستجو با اطلاعات استخراج شده است

# %%
stwd = ['همچنان', 'مدت', 'چیز', 'سایر', 'جا', 'طی', 'کل', 'کنونی', 'بیرون','های', 'مثلا', 'کامل','ها', 'کاملا','گیرد','شود','است', 'آنکه', 
            'موارد', 'واقعی', 'امور', 'اکنون', 'بطور', 'بخشی', 'تحت', 'چگونه', 'عدم', 'نوعی', 'حاضر', 'وضع', 'مقابل', 'کنار', 'خویش', 'نگاه', 'درون',
            'زمانی', 'بنابراین', 'تو', 'خیلی', 'بزرگ', 'خودش', 'جز', 'اینجا', 'مختلف', 'توسط', 'نوع', 'همچنین', 'آنجا', 'قبل', 'جناح', 'اینها', 'طور', 'شاید',
            'ایشان', 'جهت', 'طریق', 'مانند', 'پیدا', 'ممکن', 'کسانی', 'جای', 'کسی', 'غیر', 'بی', 'قابل', 'درباره', 'جدید', 'وقتی', 'اخیر', 'چرا', 'بیش',
            'روی', 'طرف', 'جریان', 'زیر', 'آنچه', 'البته', 'فقط', 'چیزی', 'چون', 'برابر', 'هنوز', 'بخش', 'زمینه', 'بین', 'بدون', 'استفاد', 'همان', 'نشان',
            'بسیاری', 'بعد', 'عمل', 'روز', 'اعلام', 'چند', 'آنان', 'بلکه', 'امروز', 'تمام', 'بیشتر', 'آیا', 'برخی', 'علیه', 'دیگری', 'ویژه', 'گذشته', 'انجام',
            'حتی', 'داده', 'راه', 'سوی', 'ولی', 'زمان', 'حال', 'تنها', 'بسیار', 'یعنی', 'عنوان', 'همین', 'هبچ', 'پیش', 'وی', 'یکی', 'اینکه', 'وجود'
            , 'شما', 'پس', 'چنین', 'میان', 'مورد', 'چه', 'اگر', 'همه', 'نه', 'دیگر', 'آنها', 'باید', 'هر', 'او', 'ما', 'من', 'تا', 'نیز', 'اما', 
            'یک', 'خود', 'بر', 'یا', 'هم','ای', 'را','دارد', 'این',"می", 'با','دارد','،',',','.', 'آن', 'برای',"بطور", 'و', 'در', 'به', 'که', 'از']

stwd = set(stwd)

# %%
wordlist = word_tokenize(textnor)
wordlist
# Out:
# ['متن',
#  'کاوی',
#  '،',
#  'به',
#  'داده',
#  'کاوی',
#  'ای',
#  'که',
#  'بر',
#  'روی',
#  'متن',
#  'ها',
#  'انجام',
#  'شود',
#  'اشااررررره',
#  'دارد',
#  '.',
#  'همچنین',
#  'به',
#  'عنوان',
#  'آنالیز',
#  'متن',
#  'نیز',
#  'شناخته',
#  'می',
#  'شود',
#  'که',
#  'منظور',
#  'از',
#  'آن',
#  'فرایندها',
#  'استخراج',
#  'مکرر',
#  'اطلاعات',
#  'با',
#  'کیفیت',
#  'از',
#  'متن',
#  'است',
#  '.',
#  'اطلاعات',
#  'پر',
#  'کیفیت',
#  '،',
#  'به',
#  'طور',
#  'معمول',
#  'از',
#  'فهم',
#  'الگوها',
#  'و',
#  'گرایش',
#  'ها',
#  'از',
#  'طریق',
#  'معانی',
#  'و',
#  'به',
#  'وسیلهٔ',
#  'یادگیری',
#  'الگوهای',
#  'آماری',
#  'حاصل',
#  'می',
#  'شود',
#  '.',
#  'متن',
#  'کاوی',
#  'معمولاً',
#  'درگیر',
#  'در',
#  'فرایند',
#  'ساختاردهی',
#  'به',
#  'ورودی',
#  'های',
#  'متنی',
#  '(',
#  'معمولاً',
#  'تجزیه',
#  '،',
#  'همراه',
#  'با',
#  'افزودن',
#  'برخی',
#  'ویژگی',
#  'ها',
#  'تفاسیر',
#  'زبانی',
#  'و',
#  'حذف',
#  'موارد',
#  'اضافی',
#  'و',
#  'درج',
#  'موارد',
#  'بعدی',
#  'در',
#  'پایگاه',
#  'داده',
#  'انجام',
#  'می',
#  'گیرد',
#  ')',
#  '،',
#  'استخراج',
#  'الگوهای',
#  'درون',
#  'داده',
#  'های',
#  'ساختار',
#  'یافته',
#  '،',
#  'و',
#  'در',
#  'نهایت',
#  'ارزیابی',
#  'و',
#  'تفسیر',
#  'خروجی',
#  'ها',
#  'است',
#  '.',
#  '«',
#  'پر',
#  'کیفیت',
#  '»',
#  'در',
#  'متن',
#  'کاوی',
#  'معمولاً',
#  'به',
#  'ترکیبی',
#  'از',
#  'مرتبط',
#  'بودن',
#  '،',
#  'نو',
#  'ظهور',
#  'بودن',
#  'و',
#  'جالب',
#  'بودن',
#  'اشاره',
#  'دارد',
#  '.',
#  'وظایف',
#  'متن',
#  'کاوی',
#  'معمول',
#  'شامل',
#  'دسته',
#  'بندی',
#  'متون',
#  '،',
#  'خوشه',
#  'بندی',
#  'متون',
#  '،',
#  'استخراج',
#  'معنی',
#  'و',
#  'مفهوم',
#  '،',
#  'تولید',
#  'رده',
#  'بندی',
#  'دانه',
#  'ای',
#  '،',
#  'تجزیه',
#  'و',
#  'تحلیل',
#  'احساسات',
#  '،',
#  'خلاصه',
#  'کردن',
#  'اسناد',
#  'و',
#  'مدلسازی',
#  'ارتباط',
#  'موجودیت',
#  'ها',
#  'است',
#  '.',
#  '(',
#  'بطور',
#  'مثال',
#  'یادگیری',
#  'ارتباط',
#  'بین',
#  'موجودیتها',
#  ')',
#  'آنالیز',
#  'متن',
#  'درگیر',
#  'در',
#  'بازیابی',
#  'اطلاعات',
#  '،',
#  'آنالیز',
#  'لغوی',
#  'برای',
#  'مطالعه',
#  'توزیع',
#  'فرکانس',
#  'لغات',
#  '،',
#  'شناخت',
#  'الگو',
#  '،',
#  'برچسب',
#  'گذاری/حاشیه',
#  'نویسی',
#  '،',
#  'استخراج',
#  'اطلاعات',
#  '،',
#  'تکنیک',
#  'های',
#  'داده',
#  'کاوی',
#  'شامل',
#  'آنالیز',
#  'اتصال',
#  'و',
#  'ارتباط',
#  '،',
#  'بصری',
#  'سازی',
#  '،',
#  'و',
#  'آنالیز',
#  'پیشگویانه',
#  'است',
#  '.',
#  'هدف',
#  'نهایی',
#  '،',
#  'اساساً',
#  'تبدیل',
#  'متن',
#  'به',
#  'داده',
#  'برای',
#  'آنالیز',
#  'از',
#  'طریق',
#  'کاربرد',
#  'پردازش',
#  'زبان',
#  'های',
#  'طبیعی',
#  'و',
#  'متدهای',
#  'تحلیلی',
#  'است',
#  '.',
#  'یک',
#  'کاربرد',
#  'معمول',
#  '،',
#  'جهت',
#  'اسکن',
#  'مجموعه',
#  'ای',
#  'از',
#  'اسناد',
#  'نوشته',
#  'شده',
#  'در',
#  'یک',
#  'زبان',
#  'طبیعی',
#  'و',
#  'مدل',
#  'کردن',
#  'مجموعه',
#  'اسناد',
#  'برای',
#  'اهداف',
#  'کلاس',
#  'بندی',
#  'پیشگویانه',
#  'یا',
#  'پرکردن',
#  'یک',
#  'پایگاه',
#  'داده',
#  'یا',
#  'ایندکس',
#  'جستجو',
#  'با',
#  'اطلاعات',
#  'استخراج',
#  'شده_است']

# %%
dicwordcount = {}

for w in wordlist:
    if w not in dicwordcount.keys():
        dicwordcount[w] = 1
    else:
        dicwordcount[w] +=1
dicwordcount
# Out:
# {'(': 2,
#  ')': 2,
#  '.': 8,
#  '«': 1,
#  '»': 1,
#  '،': 20,
#  'آماری': 1,
#  'آن': 1,
#  'آنالیز': 6,
#  'اتصال': 1,
#  'احساسات': 1,
#  'ارتباط': 3,
#  'ارزیابی': 1,
#  'از': 7,
#  'اساساً': 1,
#  'است': 5,
#  'استخراج': 5,
#  'اسناد': 3,
#  'اسکن': 1,
#  'اشااررررره': 1,
#  'اشاره': 1,
#  'اضافی': 1,
#  'اطلاعات': 5,
#  'افزودن': 1,
#  'الگو': 1,
#  'الگوها': 1,
#  'الگوهای': 2,
#  'انجام': 2,
#  'اهداف': 1,
#  'ای': 3,
#  'ایندکس': 1,
#  'با': 3,
#  'بازیابی': 1,
#  'بر': 1,
#  'برای': 3,
#  'برخی': 1,
#  'برچسب': 1,
#  'بصری': 1,
#  'بطور': 1,
#  'بعدی': 1,
#  'بندی': 4,
#  'به': 7,
#  'بودن': 3,
#  'بین': 1,
#  'تبدیل': 1,
#  'تجزیه': 2,
#  'تحلیل': 1,
#  'تحلیلی': 1,
#  'ترکیبی': 1,
#  'تفاسیر': 1,
#  'تفسیر': 1,
#  'توزیع': 1,
#  'تولید': 1,
#  'تکنیک': 1,
#  'جالب': 1,
#  'جستجو': 1,
#  'جهت': 1,
#  'حاصل': 1,
#  'حذف': 1,
#  'خروجی': 1,
#  'خلاصه': 1,
#  'خوشه': 1,
#  'داده': 6,
#  'دارد': 2,
#  'دانه': 1,
#  'در': 6,
#  'درج': 1,
#  'درون': 1,
#  'درگیر': 2,
#  'دسته': 1,
#  'رده': 1,
#  'روی': 1,
#  'زبان': 2,
#  'زبانی': 1,
#  'ساختار': 1,
#  'ساختاردهی': 1,
#  'سازی': 1,
#  'شامل': 2,
#  'شده': 1,
#  'شده_است': 1,
#  'شناخت': 1,
#  'شناخته': 1,
#  'شود': 3,
#  'طبیعی': 2,
#  'طریق': 2,
#  'طور': 1,
#  'ظهور': 1,
#  'عنوان': 1,
#  'فرایند': 1,
#  'فرایندها': 1,
#  'فرکانس': 1,
#  'فهم': 1,
#  'لغات': 1,
#  'لغوی': 1,
#  'متدهای': 1,
#  'متن': 9,
#  'متنی': 1,
#  'متون': 2,
#  'مثال': 1,
#  'مجموعه': 2,
#  'مدل': 1,
#  'مدلسازی': 1,
#  'مرتبط': 1,
#  'مطالعه': 1,
#  'معانی': 1,
#  'معمول': 3,
#  'معمولاً': 3,
#  'معنی': 1,
#  'مفهوم': 1,
#  'منظور': 1,
#  'موارد': 2,
#  'موجودیت': 1,
#  'موجودیتها': 1,
#  'مکرر': 1,
#  'می': 3,
#  'نهایت': 1,
#  'نهایی': 1,
#  'نو': 1,
#  'نوشته': 1,
#  'نویسی': 1,
#  'نیز': 1,
#  'ها': 5,
#  'های': 4,
#  'هدف': 1,
#  'همراه': 1,
#  'همچنین': 1,
#  'و': 14,
#  'ورودی': 1,
#  'وسیلهٔ': 1,
#  'وظایف': 1,
#  'ویژگی': 1,
#  'پایگاه': 2,
#  'پر': 2,
#  'پردازش': 1,
#  'پرکردن': 1,
#  'پیشگویانه': 2,
#  'کاربرد': 2,
#  'کاوی': 6,
#  'کردن': 2,
#  'کلاس': 1,
#  'که': 2,
#  'کیفیت': 3,
#  'گذاری/حاشیه': 1,
#  'گرایش': 1,
#  'گیرد': 1,
#  'یا': 2,
#  'یادگیری': 2,
#  'یافته': 1,
#  'یک': 3}

# %%
dicwordcount2 = {}
    
for w in wordlist:
    if w not in stwd:
        if w not in dicwordcount2.keys():
            dicwordcount2[w] = 1
        else:
            dicwordcount2[w] +=1
            
dicwordcount2
# Out:
# {'(': 2,
#  ')': 2,
#  '«': 1,
#  '»': 1,
#  'آماری': 1,
#  'آنالیز': 6,
#  'اتصال': 1,
#  'احساسات': 1,
#  'ارتباط': 3,
#  'ارزیابی': 1,
#  'اساساً': 1,
#  'استخراج': 5,
#  'اسناد': 3,
#  'اسکن': 1,
#  'اشااررررره': 1,
#  'اشاره': 1,
#  'اضافی': 1,
#  'اطلاعات': 5,
#  'افزودن': 1,
#  'الگو': 1,
#  'الگوها': 1,
#  'الگوهای': 2,
#  'اهداف': 1,
#  'ایندکس': 1,
#  'بازیابی': 1,
#  'برچسب': 1,
#  'بصری': 1,
#  'بعدی': 1,
#  'بندی': 4,
#  'بودن': 3,
#  'تبدیل': 1,
#  'تجزیه': 2,
#  'تحلیل': 1,
#  'تحلیلی': 1,
#  'ترکیبی': 1,
#  'تفاسیر': 1,
#  'تفسیر': 1,
#  'توزیع': 1,
#  'تولید': 1,
#  'تکنیک': 1,
#  'جالب': 1,
#  'جستجو': 1,
#  'حاصل': 1,
#  'حذف': 1,
#  'خروجی': 1,
#  'خلاصه': 1,
#  'خوشه': 1,
#  'دانه': 1,
#  'درج': 1,
#  'درگیر': 2,
#  'دسته': 1,
#  'رده': 1,
#  'زبان': 2,
#  'زبانی': 1,
#  'ساختار': 1,
#  'ساختاردهی': 1,
#  'سازی': 1,
#  'شامل': 2,
#  'شده': 1,
#  'شده_است': 1,
#  'شناخت': 1,
#  'شناخته': 1,
#  'طبیعی': 2,
#  'ظهور': 1,
#  'فرایند': 1,
#  'فرایندها': 1,
#  'فرکانس': 1,
#  'فهم': 1,
#  'لغات': 1,
#  'لغوی': 1,
#  'متدهای': 1,
#  'متن': 9,
#  'متنی': 1,
#  'متون': 2,
#  'مثال': 1,
#  'مجموعه': 2,
#  'مدل': 1,
#  'مدلسازی': 1,
#  'مرتبط': 1,
#  'مطالعه': 1,
#  'معانی': 1,
#  'معمول': 3,
#  'معمولاً': 3,
#  'معنی': 1,
#  'مفهوم': 1,
#  'منظور': 1,
#  'موجودیت': 1,
#  'موجودیتها': 1,
#  'مکرر': 1,
#  'نهایت': 1,
#  'نهایی': 1,
#  'نو': 1,
#  'نوشته': 1,
#  'نویسی': 1,
#  'هدف': 1,
#  'همراه': 1,
#  'ورودی': 1,
#  'وسیلهٔ': 1,
#  'وظایف': 1,
#  'ویژگی': 1,
#  'پایگاه': 2,
#  'پر': 2,
#  'پردازش': 1,
#  'پرکردن': 1,
#  'پیشگویانه': 2,
#  'کاربرد': 2,
#  'کاوی': 6,
#  'کردن': 2,
#  'کلاس': 1,
#  'کیفیت': 3,
#  'گذاری/حاشیه': 1,
#  'گرایش': 1,
#  'یادگیری': 2,
#  'یافته': 1}

# %%
for k,v in dicwordcount.items():
    print((k,v))
# Out:
# ('متن', 9)
# ('کاوی', 6)
# ('،', 20)
# ('به', 7)
# ('داده', 6)
# ('ای', 3)
# ('که', 2)
# ('بر', 1)
# ('روی', 1)
# ('ها', 5)
# ('انجام', 2)
# ('شود', 3)
# ('اشااررررره', 1)
# ('دارد', 2)
# ('.', 8)
# ('همچنین', 1)
# ('عنوان', 1)
# ('آنالیز', 6)
# ('نیز', 1)
# ('شناخته', 1)
# ('می', 3)
# ('منظور', 1)
# ('از', 7)
# ('آن', 1)
# ('فرایندها', 1)
# ('استخراج', 5)
# ('مکرر', 1)
# ('اطلاعات', 5)
# ('با', 3)
# ('کیفیت', 3)
# ('است', 5)
# ('پر', 2)
# ('طور', 1)
# ('معمول', 3)
# ('فهم', 1)
# ('الگوها', 1)
# ('و', 14)
# ('گرایش', 1)
# ('طریق', 2)
# ('معانی', 1)
# ('وسیلهٔ', 1)
# ('یادگیری', 2)
# ('الگوهای', 2)
# ('آماری', 1)
# ('حاصل', 1)
# ('معمولاً', 3)
# ('درگیر', 2)
# ('در', 6)
# ('فرایند', 1)
# ('ساختاردهی', 1)
# ('ورودی', 1)
# ('های', 4)
# ('متنی', 1)
# ('(', 2)
# ('تجزیه', 2)
# ('همراه', 1)
# ('افزودن', 1)
# ('برخی', 1)
# ('ویژگی', 1)
# ('تفاسیر', 1)
# ('زبانی', 1)
# ('حذف', 1)
# ('موارد', 2)
# ('اضافی', 1)
# ('درج', 1)
# ('بعدی', 1)
# ('پایگاه', 2)
# ('گیرد', 1)
# (')', 2)
# ('درون', 1)
# ('ساختار', 1)
# ('یافته', 1)
# ('نهایت', 1)
# ('ارزیابی', 1)
# ('تفسیر', 1)
# ('خروجی', 1)
# ('«', 1)
# ('»', 1)
# ('ترکیبی', 1)
# ('مرتبط', 1)
# ('بودن', 3)
# ('نو', 1)
# ('ظهور', 1)
# ('جالب', 1)
# ('اشاره', 1)
# ('وظایف', 1)
# ('شامل', 2)
# ('دسته', 1)
# ('بندی', 4)
# ('متون', 2)
# ('خوشه', 1)
# ('معنی', 1)
# ('مفهوم', 1)
# ('تولید', 1)
# ('رده', 1)
# ('دانه', 1)
# ('تحلیل', 1)
# ('احساسات', 1)
# ('خلاصه', 1)
# ('کردن', 2)
# ('اسناد', 3)
# ('مدلسازی', 1)
# ('ارتباط', 3)
# ('موجودیت', 1)
# ('بطور', 1)
# ('مثال', 1)
# ('بین', 1)
# ('موجودیتها', 1)
# ('بازیابی', 1)
# ('لغوی', 1)
# ('برای', 3)
# ('مطالعه', 1)
# ('توزیع', 1)
# ('فرکانس', 1)
# ('لغات', 1)
# ('شناخت', 1)
# ('الگو', 1)
# ('برچسب', 1)
# ('گذاری/حاشیه', 1)
# ('نویسی', 1)
# ('تکنیک', 1)
# ('اتصال', 1)
# ('بصری', 1)
# ('سازی', 1)
# ('پیشگویانه', 2)
# ('هدف', 1)
# ('نهایی', 1)
# ('اساساً', 1)
# ('تبدیل', 1)
# ('کاربرد', 2)
# ('پردازش', 1)
# ('زبان', 2)
# ('طبیعی', 2)
# ('متدهای', 1)
# ('تحلیلی', 1)
# ('یک', 3)
# ('جهت', 1)
# ('اسکن', 1)
# ('مجموعه', 2)
# ('نوشته', 1)
# ('شده', 1)
# ('مدل', 1)
# ('اهداف', 1)
# ('کلاس', 1)
# ('یا', 2)
# ('پرکردن', 1)
# ('ایندکس', 1)
# ('جستجو', 1)
# ('شده_است', 1)

# %%
import operator
sorted_Dict = sorted(dicwordcount.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_Dict)
# Out:
# [('،', 20), ('و', 14), ('متن', 9), ('.', 8), ('به', 7), ('از', 7), ('کاوی', 6), ('داده', 6), ('آنالیز', 6), ('در', 6), ('ها', 5), ('استخراج', 5), ('اطلاعات', 5), ('است', 5), ('های', 4), ('بندی', 4), ('ای', 3), ('شود', 3), ('می', 3), ('با', 3), ('کیفیت', 3), ('معمول', 3), ('معمولاً', 3), ('بودن', 3), ('اسناد', 3), ('ارتباط', 3), ('برای', 3), ('یک', 3), ('که', 2), ('انجام', 2), ('دارد', 2), ('پر', 2), ('طریق', 2), ('یادگیری', 2), ('الگوهای', 2), ('درگیر', 2), ('(', 2), ('تجزیه', 2), ('موارد', 2), ('پایگاه', 2), (')', 2), ('شامل', 2), ('متون', 2), ('کردن', 2), ('پیشگویانه', 2), ('کاربرد', 2), ('زبان', 2), ('طبیعی', 2), ('مجموعه', 2), ('یا', 2), ('بر', 1), ('روی', 1), ('اشااررررره', 1), ('همچنین', 1), ('عنوان', 1), ('نیز', 1), ('شناخته', 1), ('منظور', 1), ('آن', 1), ('فرایندها', 1), ('مکرر', 1), ('طور', 1), ('فهم', 1), ('الگوها', 1), ('گرایش', 1), ('معانی', 1), ('وسیلهٔ', 1), ('آماری', 1), ('حاصل', 1), ('فرایند', 1), ('ساختاردهی', 1), ('ورودی', 1), ('متنی', 1), ('همراه', 1), ('افزودن', 1), ('برخی', 1), ('ویژگی', 1), ('تفاسیر', 1), ('زبانی', 1), ('حذف', 1), ('اضافی', 1), ('درج', 1), ('بعدی', 1), ('گیرد', 1), ('درون', 1), ('ساختار', 1), ('یافته', 1), ('نهایت', 1), ('ارزیابی', 1), ('تفسیر', 1), ('خروجی', 1), ('«', 1), ('»', 1), ('ترکیبی', 1), ('مرتبط', 1), ('نو', 1), ('ظهور', 1), ('جالب', 1), ('اشاره', 1), ('وظایف', 1), ('دسته', 1), ('خوشه', 1), ('معنی', 1), ('مفهوم', 1), ('تولید', 1), ('رده', 1), ('دانه', 1), ('تحلیل', 1), ('احساسات', 1), ('خلاصه', 1), ('مدلسازی', 1), ('موجودیت', 1), ('بطور', 1), ('مثال', 1), ('بین', 1), ('موجودیتها', 1), ('بازیابی', 1), ('لغوی', 1), ('مطالعه', 1), ('توزیع', 1), ('فرکانس', 1), ('لغات', 1), ('شناخت', 1), ('الگو', 1), ('برچسب', 1), ('گذاری/حاشیه', 1), ('نویسی', 1), ('تکنیک', 1), ('اتصال', 1), ('بصری', 1), ('سازی', 1), ('هدف', 1), ('نهایی', 1), ('اساساً', 1), ('تبدیل', 1), ('پردازش', 1), ('متدهای', 1), ('تحلیلی', 1), ('جهت', 1), ('اسکن', 1), ('نوشته', 1), ('شده', 1), ('مدل', 1), ('اهداف', 1), ('کلاس', 1), ('پرکردن', 1), ('ایندکس', 1), ('جستجو', 1), ('شده_است', 1)]

# %%
from collections import Counter
Text = open(r"D:\Text9\data\Text.txt",mode='r',encoding='utf-8').read()
#Text = Text.split()
Text = word_tokenize(Text)
count = Counter(Text)
count
count.most_common(100)
# Out:
# [('،', 20),
#  ('و', 14),
#  ('.', 9),
#  ('متن', 8),
#  ('از', 7),
#  ('به', 6),
#  ('آنالیز', 6),
#  ('در', 6),
#  ('استخراج', 5),
#  ('اطلاعات', 5),
#  ('است', 5),
#  ('کاوی', 4),
#  ('داده', 4),
#  ('با', 3),
#  ('کیفیت', 3),
#  ('معمول', 3),
#  ('معمولاً', 3),
#  ('بودن', 3),
#  ('اسناد', 3),
#  ('ارتباط', 3),
#  ('برای', 3),
#  ('یک', 3),
#  ('که', 2),
#  ('انجام', 2),
#  ('اشاره', 2),
#  ('دارد', 2),
#  ('فرایند', 2),
#  ('پر', 2),
#  ('طریق', 2),
#  ('یادگیری', 2),
#  ('الگوهای', 2),
#  ('درگیر', 2),
#  ('(', 2),
#  ('تجزیه', 2),
#  ('موارد', 2),
#  ('پایگاه', 2),
#  (')', 2),
#  ('شامل', 2),
#  ('متون', 2),
#  ('کردن', 2),
#  ('پیشگویانه', 2),
#  ('کاربرد', 2),
#  ('طبیعی', 2),
#  ('یا', 2),
#  ('\ufeffمتن\u200cکاوي', 1),
#  ('داده\u200cکاوي\u200cاي', 1),
#  ('بر', 1),
#  ('روی', 1),
#  ('شود', 1),
#  ('همچنین', 1),
#  ('عنوان', 1),
#  ('نیز', 1),
#  ('شناخته_می\u200cشود', 1),
#  ('منظور', 1),
#  ('آن', 1),
#  ('به\u200cطور', 1),
#  ('فهم', 1),
#  ('الگوها', 1),
#  ('گرایش\u200cها', 1),
#  ('معانی', 1),
#  ('وسیلهٔ', 1),
#  ('آماری', 1),
#  ('حاصل', 1),
#  ('می\u200cشود', 1),
#  ('ساختاردهی', 1),
#  ('ورودی\u200cهای', 1),
#  ('متنی', 1),
#  ('همراه', 1),
#  ('افزودن', 1),
#  ('برخی', 1),
#  ('ویژگی\u200cها', 1),
#  ('تفاسیر', 1),
#  ('زبانی', 1),
#  ('حذف', 1),
#  ('اضافی', 1),
#  ('درج', 1),
#  ('بعدی', 1),
#  ('می\u200cگیرد', 1),
#  ('درون', 1),
#  ('داده\u200cهای', 1),
#  ('ساختار', 1),
#  ('یافته', 1),
#  ('نهایت', 1),
#  ('ارزیابی', 1),
#  ('تفسیر', 1),
#  ('خروجی\u200cها', 1),
#  ('«', 1),
#  ('»', 1),
#  ('ترکیبی', 1),
#  ('مرتبط', 1),
#  ('نو', 1),
#  ('ظهور', 1),
#  ('جالب', 1),
#  ('وظایف', 1),
#  ('دسته\u200cبندی', 1),
#  ('خوشه', 1),
#  ('بندی', 1),
#  ('معنی', 1),
#  ('مفهوم', 1),
#  ('تولید', 1)]

# %%
import csv
with open(r"D:\Text9\data\wordcountexport.csv", 'w', newline='', encoding='utf-8') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for key, value in count.items():
        spamwriter.writerow([key, value])

# %%
from wordcloud_fa import WordCloudFa

wc = WordCloudFa(width=1200, height=800,background_color="white",stopwords=stwd)

Text = "متن‌کاوی، به داده‌کاوی‌ای که بر روی متن انجام شود اشاره دارد. همچنین به عنوان آنالیز متن نیز شناخته می‌شود که منظور از آن فرایند استخراج اطلاعات با کیفیت از متن است. اطلاعات پر کیفیت، به‌طور معمول از فهم الگوها و گرایش‌ها از طریق معانی و به وسیلهٔ یادگیری الگوهای آماری حاصل می‌شود. متن کاوی معمولاً درگیر در فرایند ساختاردهی به ورودی‌های متنی (معمولاً تجزیه، همراه با افزودن برخی ویژگی‌ها تفاسیر زبانی و حذف موارد اضافی و درج موارد بعدی در پایگاه داده انجام می‌گیرد)، استخراج الگوهای درون داده‌های ساختار یافته، و در نهایت ارزیابی و تفسیر خروجی‌ها است. «پر کیفیت» در متن کاوی معمولاً به ترکیبی از مرتبط بودن، نو ظهور بودن و جالب بودن اشاره دارد. وظایف متن کاوی معمول شامل دسته‌بندی متون، خوشه بندی متون، استخراج معنی و مفهوم، تولید رده‌بندی دانه‌ای، تجزیه و تحلیل احساسات، خلاصه کردن اسناد و مدلسازی ارتباط موجودیت‌ها است. (بطور مثال یادگیری ارتباط بین موجودیتها) آنالیز متن درگیر در بازیابی اطلاعات، آنالیز لغوی برای مطالعه توزیع فرکانس لغات، شناخت الگو، برچسب گذاری/حاشیه نویسی، استخراج اطلاعات، تکنیک‌های داده کاوی شامل آنالیز اتصال و ارتباط، بصری سازی، و آنالیز پیشگویانه است. هدف نهایی، اساساً تبدیل متن به داده برای آنالیز از طریق کاربرد پردازش زبان‌های طبیعی و متدهای تحلیلی است. یک کاربرد معمول، جهت اسکن مجموعه‌ای از اسناد نوشته شده در یک زبان طبیعی و مدل کردن مجموعه اسناد برای اهداف کلاس‌بندی پیشگویانه یا پرکردن یک پایگاه داده یا ایندکس جستجو با اطلاعات استخراج شده‌است"

word_cloud = wc.generate(Text)

# %%
image = word_cloud.to_image()
image.show()
image.save(r'D:\Text9\data\persian-example.png')
